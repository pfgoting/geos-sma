# %%
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\King\Anaconda2\lib\site-packages\IPython\core\magics\pylab.py:161: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from testrun import *

# %%
x = [x[0] for x in vals]
y = [x[1] for x in vals]

plt.plot(*zip(x,y))

# %%
fil = r"C:\Users\King\Desktop\GEOSApp\PRISM 1.0.0\computed_parms\out\Orphan\UT_2017_03_27_07_26_28\V2\20170327072628.KMI.001.C1.dis.V2c"
with open(fil,'rb') as f:
    lines = f.readlines()

# %%
x = map(lambda x: float(x.strip()),lines[55:11654])
plt.plot(x)
